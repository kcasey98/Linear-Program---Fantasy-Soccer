# %%
import pandas as pd
from pulp import *
PATH = 'data/'

current_df = pd.read_csv(PATH + '2021-22/gws/merged_gw.csv', index_col=False)
gw_35 = current_df[current_df.GW == 35]


GW_dict = {}
GWs = current_df.GW.unique()
             
# Solving for the first x weeks, first part before free hit
players = current_df[current_df.GW == 1].name.unique()
for GW in sorted(GWs)[:6]:
    print(GW)
    player_price_dict = {} # key: player, value: (name, team, position, price, total points)
    print("Number players in week {} is {}".format(GW, len(players)))
    for i, player in enumerate(players):
        player_entries = current_df[current_df.name == player]
        total_points = player_entries[player_entries.GW <= GW]['total_points'].sum()
        player_team = player_entries[player_entries.GW == 1]['team'].values[0]
        player_price = player_entries[player_entries.GW == 1]['value'].values[0]
        player_position = player_entries[player_entries.GW == 1]['position'].values[0]
        player_name = player_entries[player_entries.GW == 1]['name']
        if player not in player_price_dict:
                val = (player,player_team, player_position, player_price, total_points)
                player_price_dict[player] = val
    GW_dict[GW] = player_price_dict
        #print("Player {} had {} price total in all {} played.".format(player, player_price, len(player_entries)))

gw_35.head()
data = gw_35[['name', 'team', 'position', 'total_points', 'value']]        
data.head()

# Helper variables
POS = data.position.unique()
CLUBS = data.team.unique()

BUDGET = 1000
pos_available = {
'DEF': 5,
'FWD': 3,
'MID': 5,
'GK': 2,
}

# Initialize Variables
solver_dict = {}
points_dict = {}
each_team = {}
budget_add = 0;
numbers = 0
for GW in GWs[:6]:
    print(GW)
    cur_player_price_dict = GW_dict[GW]
    names, teams, positions, prices, points = list(zip(*cur_player_price_dict.values()))
    players = [LpVariable("player_" + str(i), cat="Binary") for i in range(len(names))]
    # Initialize the problem
    prob = LpProblem("FPL_Player_Choices", LpMaximize)
    # Define the objective
    prob += lpSum(players[i] * points[i] for i in range(len(names))) # Objective
    # Build the constraints
    prob += lpSum(players[i] * prices[i] for i in range(len(names))) <= BUDGET # Budget Limit

    for pos in POS:
        prob += lpSum(players[i] for i in range(len(names)) if positions[i] == pos) <= pos_available[pos] # Position Limit

    for club in CLUBS:
        prob += lpSum(players[i] for i in range(len(names)) if teams[i] == club) <= 3 # Club Limit
    # Solve the problem
    prob.solve()
    for v in prob.variables():
        if v.varValue != 0:
            index = int(v.name.split("_")[1])
            name = names[index]
            club = teams[index]
            position = positions[index]
            point = points[index]
            price = prices[index]
            solver_dict[name] = (name,club,position,price,point)
            numbers += 1
            # print(name, position, club, point, price, sep=" | ")
            score = str(prob.objective)
            constraint = [str(const) for const in prob.constraints.values()][0]
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraint = constraint.replace(v.name, str(v.varValue))

    score_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', score) )
    constraint_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', constraint) )

    points_dict[GW] = value(prob.objective)
    each_team[GW] = solver_dict
#     names2, prices2 = list(zip(*solver_dict.values()))
#     print(names2)
    solver_dict = {}
    numbers = 0
    
print(points_dict)
print(each_team)


# Solving for the best teams from each x week until end, (second half)
for GW in sorted(GWs)[:6]:
    if GW == 1:
        current_team = each_team[GW]
    else:
        current_team = each_team[GW-1]
    print("current team")
    print(current_team)
    c_names, c_teams, c_positions, c_prices, c_points = list(zip(*current_team.values()))
    player_price_dict = {} # key: player, value: (name, team, position, price, total points)
    players = current_df[current_df.GW == GW].name.unique()
    for i, player in enumerate(players):
        player_entries = current_df[current_df.name == player]
        total_points = player_entries[player_entries.GW >= GW]['total_points'].sum()
        player_team = player_entries[player_entries.GW == GW]['team'].values[0]
        player_price = player_entries[player_entries.GW == GW]['value'].values[0]
        player_position = player_entries[player_entries.GW == GW]['position'].values[0]
        player_name = player_entries[player_entries.GW == GW]['name']
        if player not in player_price_dict:
                val = (player,player_team, player_position, player_price, total_points)
                if player in current_team:
                    c_name, c_team, c_position, c_price, c_point = current_team[player];
                    val = (player,player_team, player_position, c_price, total_points)
                player_price_dict[player] = val             
    GW_dict[GW] = player_price_dict
        #print("Player {} had {} price total in all {} played.".format(player, player_price, len(player_entries)))


BUDGET = 1000
pos_available = {
'DEF': 5,
'FWD': 3,
'MID': 5,
'GK': 2,
}

# Initialize Variables
solver_dict = {}
points_dict = {}
each_team = {}
numbers = 0
for GW in GWs[:6]:
    print(GW)
    cur_player_price_dict = GW_dict[GW]
    names, teams, positions, prices, points = list(zip(*cur_player_price_dict.values()))
    players = [LpVariable("player_" + str(i), cat="Binary") for i in range(len(names))]
    # Initialize the problem
    prob = LpProblem("FPL_Player_Choices", LpMaximize)
    # Define the objective
    prob += lpSum(players[i] * points[i] for i in range(len(names))) # Objective
    # Build the constraints
    prob += lpSum(players[i] * prices[i] for i in range(len(names))) <= BUDGET # Budget Limit

    for pos in POS:
        prob += lpSum(players[i] for i in range(len(names)) if positions[i] == pos) <= pos_available[pos] # Position Limit

    for club in CLUBS:
        prob += lpSum(players[i] for i in range(len(names)) if teams[i] == club) <= 3 # Club Limit
    # Solve the problem
    prob.solve()
    for v in prob.variables():
        if v.varValue != 0:
            index = int(v.name.split("_")[1])
            name = names[index]
            club = teams[index]
            position = positions[index]
            point = points[index]
            price = prices[index]
            solver_dict[numbers] = name
            numbers += 1
            print(name, position, club, point, price, sep=" | ")
            score = str(prob.objective)
            constraint = [str(const) for const in prob.constraints.values()][0]
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraint = constraint.replace(v.name, str(v.varValue))

    score_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', score) )
    constraint_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', constraint) )

    points_dict[GW] = value(prob.objective) #store the points per week
    each_team[GW] = solver_dict # stores team
    solver_dict = {}
    numbers = 0
    
print(points_dict)
print(each_team)
# Out:
# 1
# Number players in week 1 is 553
# 2
# Number players in week 2 is 553
# 3
# Number players in week 3 is 553
# 4
# Number players in week 4 is 553
# 5
# Number players in week 5 is 553
# 6
# Number players in week 6 is 553
# 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/0945b380c6e44383a6cbb0ba02ef7463-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/0945b380c6e44383a6cbb0ba02ef7463-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3069 RHS
# At line 3095 BOUNDS
# At line 3649 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 190 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 235 columns (235 integer (212 of which binary)) and 705 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -190
# Cbc0038I Cleaned solution of -190
# Cbc0038I Before mini branch and bound, 235 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -190 - took 0.00 seconds
# Cbc0012I Integer solution of -190 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -190, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -190 to -190
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                190.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/8722234d8acf493281e0a286971de6b9-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/8722234d8acf493281e0a286971de6b9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3109 RHS
# At line 3135 BOUNDS
# At line 3689 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 286.333 - 0.00 seconds
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 25 rows, 280 columns (280 integer (255 of which binary)) and 840 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.666667
# Cbc0038I Solution found of -286
# Cbc0038I Cleaned solution of -286
# Cbc0038I Before mini branch and bound, 278 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -286 - took 0.00 seconds
# Cbc0012I Integer solution of -286 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -286, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 250 variables fixed on reduced cost
# Cuts at root node changed objective from -286.333 to -286.333
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                286.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 3
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/f4950de050fd4230af71e689baaa0e66-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/f4950de050fd4230af71e689baaa0e66-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3140 RHS
# At line 3166 BOUNDS
# At line 3720 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 365.5 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 324 columns (324 integer (307 of which binary)) and 972 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 1
# Cbc0038I Solution found of -364
# Cbc0038I Cleaned solution of -364
# Cbc0038I Before mini branch and bound, 322 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 324 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -365.05
# Cbc0038I Reduced cost fixing fixed 315 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.87584 (2) obj. -365.05 iterations 3
# Cbc0038I Pass   2: suminf.    0.87584 (3) obj. -365.05 iterations 1
# Cbc0038I Pass   3: suminf.    0.69994 (2) obj. -365.05 iterations 3
# Cbc0038I Pass   4: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass   5: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass   6: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass   7: suminf.    0.04991 (2) obj. -365.05 iterations 2
# Cbc0038I Pass   8: suminf.    0.04991 (2) obj. -365.05 iterations 1
# Cbc0038I Pass   9: suminf.    0.87584 (3) obj. -365.05 iterations 5
# Cbc0038I Pass  10: suminf.    0.69994 (2) obj. -365.05 iterations 3
# Cbc0038I Pass  11: suminf.    1.00000 (3) obj. -365.05 iterations 1
# Cbc0038I Pass  12: suminf.    1.00000 (3) obj. -365.05 iterations 1
# Cbc0038I Pass  13: suminf.    0.50000 (2) obj. -365.5 iterations 5
# Cbc0038I Pass  14: suminf.    0.04991 (2) obj. -365.05 iterations 3
# Cbc0038I Pass  15: suminf.    0.04991 (2) obj. -365.05 iterations 1
# Cbc0038I Pass  16: suminf.    0.90018 (3) obj. -365.05 iterations 4
# Cbc0038I Pass  17: suminf.    0.04991 (2) obj. -365.05 iterations 1
# Cbc0038I Pass  18: suminf.    0.43337 (3) obj. -365.05 iterations 4
# Cbc0038I Pass  19: suminf.    0.33333 (2) obj. -365.333 iterations 1
# Cbc0038I Pass  20: suminf.    0.04991 (2) obj. -365.05 iterations 3
# Cbc0038I Pass  21: suminf.    0.87584 (2) obj. -365.05 iterations 5
# Cbc0038I Pass  22: suminf.    0.76385 (3) obj. -365.05 iterations 2
# Cbc0038I Pass  23: suminf.    0.04991 (2) obj. -365.05 iterations 4
# Cbc0038I Pass  24: suminf.    0.87584 (3) obj. -365.05 iterations 5
# Cbc0038I Pass  25: suminf.    0.69994 (2) obj. -365.05 iterations 3
# Cbc0038I Pass  26: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass  27: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass  28: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass  29: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I Pass  30: suminf.    0.69994 (2) obj. -365.05 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 318 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 324 columns, reduced to 2 rows 3 columns
# Cbc0038I Mini branch and bound improved solution from -364 to -365 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -365 - took 0.01 seconds
# Cbc0012I Integer solution of -365 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -365, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 298 variables fixed on reduced cost
# Cuts at root node changed objective from -365.5 to -365.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                365.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
# 4
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/ad49b1c53a6247b0872212d6e0b97aea-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/ad49b1c53a6247b0872212d6e0b97aea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3157 RHS
# At line 3183 BOUNDS
# At line 3737 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 428.143 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 337 columns (337 integer (317 of which binary)) and 1011 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.857143
# Cbc0038I Solution found of -423
# Cbc0038I Cleaned solution of -423
# Cbc0038I Before mini branch and bound, 335 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 337 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -424.414
# Cbc0038I Reduced cost fixing fixed 311 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.40406 (2) obj. -424.414 iterations 2
# Cbc0038I Pass   2: suminf.    0.25643 (2) obj. -424.414 iterations 3
# Cbc0038I Pass   3: suminf.    0.04321 (2) obj. -424.414 iterations 3
# Cbc0038I Pass   4: suminf.    0.04321 (2) obj. -424.414 iterations 1
# Cbc0038I Pass   5: suminf.    0.45309 (2) obj. -424.414 iterations 2
# Cbc0038I Pass   6: suminf.    0.94280 (4) obj. -424.414 iterations 4
# Cbc0038I Pass   7: suminf.    0.94280 (4) obj. -424.414 iterations 0
# Cbc0038I Pass   8: suminf.    0.68977 (2) obj. -424.414 iterations 2
# Cbc0038I Pass   9: suminf.    0.12126 (2) obj. -424.414 iterations 5
# Cbc0038I Pass  10: suminf.    1.08784 (4) obj. -424.414 iterations 5
# Cbc0038I Pass  11: suminf.    1.08784 (4) obj. -424.414 iterations 0
# Cbc0038I Pass  12: suminf.    0.17004 (2) obj. -424.414 iterations 3
# Cbc0038I Pass  13: suminf.    0.14699 (1) obj. -424.414 iterations 1
# Cbc0038I Pass  14: suminf.    0.86308 (3) obj. -424.414 iterations 6
# Cbc0038I Pass  15: suminf.    0.86308 (3) obj. -424.414 iterations 0
# Cbc0038I Pass  16: suminf.    0.17331 (1) obj. -424.414 iterations 3
# Cbc0038I Pass  17: suminf.    0.18467 (2) obj. -424.414 iterations 1
# Cbc0038I Pass  18: suminf.    0.89645 (2) obj. -424.414 iterations 5
# Cbc0038I Pass  19: suminf.    0.10662 (2) obj. -424.414 iterations 3
# Cbc0038I Pass  20: suminf.    0.09436 (1) obj. -424.414 iterations 1
# Cbc0038I Pass  21: suminf.    1.00000 (3) obj. -424.414 iterations 7
# Cbc0038I Pass  22: suminf.    0.81657 (3) obj. -424.414 iterations 2
# Cbc0038I Pass  23: suminf.    0.14699 (1) obj. -424.414 iterations 3
# Cbc0038I Pass  24: suminf.    0.17004 (2) obj. -424.414 iterations 1
# Cbc0038I Pass  25: suminf.    1.55776 (4) obj. -424.414 iterations 8
# Cbc0038I Pass  26: suminf.    0.42634 (2) obj. -424.414 iterations 3
# Cbc0038I Pass  27: suminf.    0.44164 (3) obj. -424.414 iterations 4
# Cbc0038I Pass  28: suminf.    0.42634 (2) obj. -424.414 iterations 2
# Cbc0038I Pass  29: suminf.    1.41420 (4) obj. -424.414 iterations 5
# Cbc0038I Pass  30: suminf.    0.97548 (2) obj. -424.414 iterations 2
# Cbc0038I Rounding solution of -425 is better than previous of -423
#
# Cbc0038I Before mini branch and bound, 322 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 337 columns, reduced to 4 rows 10 columns
# Cbc0038I Mini branch and bound improved solution from -425 to -426 (0.01 seconds)
# Cbc0038I Round again with cutoff of -427.228
# Cbc0038I Reduced cost fixing fixed 327 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.70475 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  31: suminf.    0.94482 (2) obj. -427.228 iterations 3
# Cbc0038I Pass  32: suminf.    0.94482 (2) obj. -427.228 iterations 0
# Cbc0038I Pass  33: suminf.    1.01508 (3) obj. -427.228 iterations 3
# Cbc0038I Pass  34: suminf.    1.01508 (3) obj. -427.228 iterations 2
# Cbc0038I Pass  35: suminf.    0.70475 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  36: suminf.    0.94482 (2) obj. -427.228 iterations 2
# Cbc0038I Pass  37: suminf.    0.94482 (2) obj. -427.228 iterations 0
# Cbc0038I Pass  38: suminf.    1.01508 (3) obj. -427.228 iterations 3
# Cbc0038I Pass  39: suminf.    0.94482 (2) obj. -427.228 iterations 3
# Cbc0038I Pass  40: suminf.    0.94482 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  41: suminf.    0.94482 (2) obj. -427.228 iterations 0
# Cbc0038I Pass  42: suminf.    0.94482 (2) obj. -427.228 iterations 0
# Cbc0038I Pass  43: suminf.    0.98547 (3) obj. -427.228 iterations 2
# Cbc0038I Pass  44: suminf.    0.70475 (2) obj. -427.228 iterations 3
# Cbc0038I Pass  45: suminf.    0.94482 (2) obj. -427.228 iterations 2
# Cbc0038I Pass  46: suminf.    0.94482 (2) obj. -427.228 iterations 0
# Cbc0038I Pass  47: suminf.    1.01508 (3) obj. -427.228 iterations 3
# Cbc0038I Pass  48: suminf.    0.89318 (3) obj. -427.228 iterations 2
# Cbc0038I Pass  49: suminf.    0.88028 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  50: suminf.    0.87142 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  51: suminf.    1.55342 (4) obj. -427.228 iterations 2
# Cbc0038I Pass  52: suminf.    1.27891 (4) obj. -427.228 iterations 1
# Cbc0038I Pass  53: suminf.    0.39752 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  54: suminf.    0.46192 (2) obj. -427.228 iterations 1
# Cbc0038I Pass  55: suminf.    1.27891 (4) obj. -427.228 iterations 1
# Cbc0038I Pass  56: suminf.    0.42857 (2) obj. -427.429 iterations 2
# Cbc0038I Pass  57: suminf.    1.27891 (4) obj. -427.228 iterations 3
# Cbc0038I Pass  58: suminf.    0.39752 (2) obj. -427.228 iterations 2
# Cbc0038I Pass  59: suminf.    0.46192 (2) obj. -427.228 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 327 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 337 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -426 - took 0.01 seconds
# Cbc0012I Integer solution of -426 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 25 rows 337 columns, reduced to 3 rows 4 columns
# Cbc0031I 1 added rows had average density of 6
# Cbc0013I At root node, 1 cuts changed objective from -428.14286 to -428.14286 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -426, took 1 iterations and 0 nodes (0.02 seconds)
# Cbc0032I Strong branching done 2 times (4 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 307 variables fixed on reduced cost
# Cuts at root node changed objective from -428.143 to -425.688
# Probing was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                426.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# 5
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/a6678cc9312b4375ae9066ca1e363e70-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/a6678cc9312b4375ae9066ca1e363e70-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3175 RHS
# At line 3201 BOUNDS
# At line 3755 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 508.571 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 358 columns (358 integer (342 of which binary)) and 1074 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.857143
# Cbc0038I Solution found of -506
# Cbc0038I Cleaned solution of -506
# Cbc0038I Before mini branch and bound, 356 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 358 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -507.157
# Cbc0038I Reduced cost fixing fixed 343 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.38568 (2) obj. -507.157 iterations 1
# Cbc0038I Pass   2: suminf.    0.73660 (2) obj. -507.157 iterations 6
# Cbc0038I Pass   3: suminf.    0.31411 (4) obj. -507.157 iterations 2
# Cbc0038I Pass   4: suminf.    0.31411 (4) obj. -507.157 iterations 0
# Cbc0038I Pass   5: suminf.    0.33718 (2) obj. -507.157 iterations 5
# Cbc0038I Pass   6: suminf.    0.02554 (1) obj. -507.157 iterations 4
# Cbc0038I Solution found of -507.157
# Cbc0038I Branch and bound needed to clear up 1 general integers
# Cbc0038I Full problem 26 rows 358 columns, reduced to 0 rows 0 columns
# Cbc0038I Cleaned solution of -508
# Cbc0038I Before mini branch and bound, 352 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -508 - took 0.00 seconds
# Cbc0012I Integer solution of -508 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -508, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 336 variables fixed on reduced cost
# Cuts at root node changed objective from -508.571 to -508.571
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                508.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 6
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/c6fcaf0b3ef24781b4572c84fbb0f5c0-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/c6fcaf0b3ef24781b4572c84fbb0f5c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3179 RHS
# At line 3205 BOUNDS
# At line 3759 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 592.25 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 365 columns (365 integer (353 of which binary)) and 1095 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.5
# Cbc0038I Solution found of -592
# Cbc0038I Cleaned solution of -592
# Cbc0038I Before mini branch and bound, 363 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -592 - took 0.00 seconds
# Cbc0012I Integer solution of -592 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -592, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 347 variables fixed on reduced cost
# Cuts at root node changed objective from -592.25 to -592.25
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                592.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# {1: 190.0, 2: 286.0, 3: 365.0, 4: 426.0, 5: 508.0, 6: 592.0}
# {1: {'Luke Thomas': ('Luke Thomas', 'Leicester', 'DEF', 45, 7), 'Mohamed Salah': ('Mohamed Salah', 'Liverpool', 'MID', 125, 17), 'Richarlison de Andrade': ('Richarlison de Andrade', 'Everton', 'FWD', 75, 11), 'Saïd Benrahma': ('Saïd Benrahma', 'West Ham', 'MID', 60, 12), 'Sergi Canós': ('Sergi Canós', 'Brentford', 'MID', 55, 11), 'Ethan Pinnock': ('Ethan Pinnock', 'Brentford', 'DEF', 45, 11), 'Marcos Alonso': ('Marcos Alonso', 'Chelsea', 'DEF', 55, 15), 'Ricardo Domingos Barbosa Pereira': ('Ricardo Domingos Barbosa Pereira', 'Leicester', 'DEF', 55, 12), 'Bruno Miguel Borges Fernandes': ('Bruno Miguel Borges Fernandes', 'Man Utd', 'MID', 120, 20), 'Hugo Lloris': ('Hugo Lloris', 'Spurs', 'GK', 55, 10), 'Michail Antonio': ('Michail Antonio', 'West Ham', 'FWD', 75, 13), 'K
elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2477.67 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 450 columns (450 integer (448 of which binary)) and 1350 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.33333
# Cbc0038I Pass   1: suminf.    0.04000 (1) obj. -2473.76 iterations 7
# Cbc0038I Solution found of -2228
# Cbc0038I Cleaned solution of -2228
# Cbc0038I Rounding solution of -2237 is better than previous of -2228
#
# Cbc0038I Before mini branch and bound, 445 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 450 columns, reduced to 4 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -2237 to -2465 (0.01 seconds)
# Cbc0038I Round again with cutoff of -2467.17
# Cbc0038I Reduced cost fixing fixed 431 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.07692 (1) obj. -2470.54 iterations 3
# Cbc0038I Pass   3: suminf.    0.59716 (2) obj. -2467.17 iterations 4
# Cbc0038I Pass   4: suminf.    0.21210 (2) obj. -2467.17 iterations 7
# Cbc0038I Pass   5: suminf.    0.21210 (2) obj. -2467.17 iterations 3
# Cbc0038I Solution found of -2477
# Cbc0038I Cleaned solution of -2477
# Cbc0038I Before mini branch and bound, 442 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -2477 - took 0.00 seconds
# Cbc0012I Integer solution of -2477 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -2477, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 442 variables fixed on reduced cost
# Cuts at root node changed objective from -2477.67 to -2477.67
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2477.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Bukayo Saka | MID | Arsenal | 168 | 65
# João Pedro Cavaco Cancelo | DEF | Man City | 185 | 60
# Aymeric Laporte | DEF | Man City | 144 | 55
# Mohamed Salah | MID | Liverpool | 256 | 125
# Jarrod Bowen | MID | West Ham | 177 | 65
# Virgil van Dijk | DEF | Liverpool | 175 | 65
# José Malheiro de Sá | GK | Wolves | 143 | 50
# James Ward-Prowse | MID | Southampton | 148 | 65
# Teemu Pukki | FWD | Norwich | 128 | 60
# Ivan Toney | FWD | Brentford | 131 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 202 | 75
# Conor Coady | DEF | Wolves | 128 | 45
# Hugo Lloris | GK | Spurs | 137 | 55
# Heung-Min Son | MID | Spurs | 223 | 100
# Emmanuel Dennis | FWD | Watford | 132 | 50
# 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/cb5a8b3b852741c1b8aab47a9db47b56-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/cb5a8b3b852741c1b8aab47a9db47b56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3307 RHS
# At line 3333 BOUNDS
# At line 3899 ENDATA
# Problem MODEL has 25 rows, 565 columns and 1695 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2415 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 448 columns (448 integer (445 of which binary)) and 1344 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.133333
# Cbc0038I Solution found of -2414
# Cbc0038I Cleaned solution of -2414
# Cbc0038I Before mini branch and bound, 446 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 448 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -2415
# Cbc0038I Reduced cost fixing fixed 442 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.13332 (2) obj. -2415 iterations 1
# Cbc0038I Pass   2: suminf.    0.13335 (3) obj. -2415 iterations 3
# Cbc0038I Pass   3: suminf.    0.13335 (3) obj. -2415 iterations 0
# Cbc0038I Pass   4: suminf.    0.13334 (2) obj. -2415 iterations 1
# Cbc0038I Pass   5: suminf.    0.13332 (2) obj. -2415 iterations 5
# Cbc0038I Pass   6: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass   7: suminf.    0.13335 (3) obj. -2415 iterations 3
# Cbc0038I Pass   8: suminf.    0.13332 (2) obj. -2415 iterations 1
# Cbc0038I Pass   9: suminf.    0.13334 (3) obj. -2415 iterations 1
# Cbc0038I Pass  10: suminf.    0.13332 (2) obj. -2415 iterations 1
# Cbc0038I Pass  11: suminf.    0.13334 (2) obj. -2415 iterations 1
# Cbc0038I Pass  12: suminf.    0.13334 (2) obj. -2415 iterations 0
# Cbc0038I Pass  13: suminf.    0.13332 (2) obj. -2415 iterations 1
# Cbc0038I Pass  14: suminf.    0.13334 (3) obj. -2415 iterations 1
# Cbc0038I Pass  15: suminf.    0.13335 (3) obj. -2415 iterations 1
# Cbc0038I Pass  16: suminf.    0.13332 (2) obj. -2415 iterations 1
# Cbc0038I Pass  17: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  18: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  19: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  20: suminf.    0.13335 (3) obj. -2415 iterations 3
# Cbc0038I Pass  21: suminf.    0.13332 (2) obj. -2415 iterations 5
# Cbc0038I Pass  22: suminf.    0.13332 (2) obj. -2415 iterations 2
# Cbc0038I Pass  23: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  24: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  25: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  26: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  27: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  28: suminf.    0.13332 (2) obj. -2415 iterations 0
# Cbc0038I Pass  29: suminf.    0.13334 (2) obj. -2415 iterations 1
# Cbc0038I Pass  30: suminf.    0.13334 (2) obj. -2415 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 444 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 448 columns, reduced to 2 rows 2 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -2414 - took 0.01 seconds
# Cbc0012I Integer solution of -2414 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -2415 to -2415 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -2414, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 439 variables fixed on reduced cost
# Cuts at root node changed objective from -2415 to -2415
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ...
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -2300, took 1 iterations and 0 nodes (0.03 seconds)
# Cbc0032I Strong branching done 2 times (3 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 458 variables fixed on reduced cost
# Cuts at root node changed objective from -2302.25 to -2238.8
# Probing was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2300.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Andrew Robertson | DEF | Liverpool | 173 | 70
# Bukayo Saka | MID | Arsenal | 164 | 63
# João Pedro Cavaco Cancelo | DEF | Man City | 171 | 60
# Aaron Ramsdale | GK | Arsenal | 127 | 45
# Mohamed Salah | MID | Liverpool | 226 | 125
# Jarrod Bowen | MID | West Ham | 171 | 64
# José Malheiro de Sá | GK | Wolves | 135 | 50
# Matthew Cash | DEF | Aston Villa | 125 | 50
# Teemu Pukki | FWD | Norwich | 117 | 59
# Ivan Toney | FWD | Brentford | 121 | 64
# Trent Alexander-Arnold | DEF | Liverpool | 180 | 75
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 139 | 69
# Gabriel Magalhães | DEF | Arsenal | 134 | 50
# Heung-Min Son | MID | Spurs | 200 | 101
# Emmanuel Dennis | FWD | Watford | 117 | 52
# 5
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/e36b583f81cc4a97a50951e9e6b79172-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/e36b583f81cc4a97a50951e9e6b79172-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3525 RHS
# At line 3551 BOUNDS
# At line 4157 ENDATA
# Problem MODEL has 25 rows, 605 columns and 1815 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2230.67 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 465 columns (465 integer (462 of which binary)) and 1395 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.031746
# Cbc0038I Solution found of -2230
# Cbc0038I Cleaned solution of -2230
# Cbc0038I Before mini branch and bound, 463 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -2230 - took 0.00 seconds
# Cbc0012I Integer solution of -2230 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -2230, took 1 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 456 variables fixed on reduced cost
# Cuts at root node changed objective from -2230.67 to -2230
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2230.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Andrew Robertson | DEF | Liverpool | 166 | 70
# Bukayo Saka | MID | Arsenal | 161 | 63
# João Pedro Cavaco Cancelo | DEF | Man City | 159 | 60
# Mason Mount | MID | Chelsea | 140 | 74
# Aaron Ramsdale | GK | Arsenal | 121 | 45
# Mohamed Salah | MID | Liverpool | 218 | 125
# Jarrod Bowen | MID | West Ham | 168 | 63
# José Malheiro de Sá | GK | Wolves | 129 | 50
# Matthew Cash | DEF | Aston Villa | 124 | 50
# Teemu Pukki | FWD | Norwich | 115 | 59
# Ivan Toney | FWD | Brentford | 119 | 63
# Trent Alexander-Arnold | DEF | Liverpool | 168 | 75
# Gabriel Magalhães | DEF | Arsenal | 126 | 50
# Heung-Min Son | MID | Spurs | 200 | 100
# Emmanuel Dennis | FWD | Watford | 116 | 52
# 6
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/kylecasey/Documents/Fantasy-Premier-League/venv/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/b1d09e4ecad047c1b6947e92d28bc225-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/b1d09e4ecad047c1b6947e92d28bc225-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3552 RHS
# At line 3578 BOUNDS
# At line 4189 ENDATA
# Problem MODEL has 25 rows, 610 columns and 1830 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2154.14 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 467 columns (467 integer (464 of which binary)) and 1401 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.172414
# Cbc0038I Solution found of -2150
# Cbc0038I Cleaned solution of -2150
# Cbc0038I Before mini branch and bound, 465 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 467 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -2151.31
# Cbc0038I Reduced cost fixing fixed 458 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.05474 (2) obj. -2151.31 iterations 1
# Cbc0038I Pass   2: suminf.    0.33573 (2) obj. -2151.31 iterations 5
# Cbc0038I Pass   3: suminf.    0.33573 (2) obj. -2151.31 iterations 0
# Cbc0038I Pass   4: suminf.    0.33573 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass   5: suminf.    0.63868 (2) obj. -2151.31 iterations 4
# Cbc0038I Pass   6: suminf.    0.42974 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass   7: suminf.    0.63868 (2) obj. -2151.31 iterations 3
# Cbc0038I Pass   8: suminf.    0.05474 (2) obj. -2151.31 iterations 3
# Cbc0038I Pass   9: suminf.    0.05474 (2) obj. -2151.31 iterations 0
# Cbc0038I Pass  10: suminf.    0.60467 (3) obj. -2151.31 iterations 5
# Cbc0038I Pass  11: suminf.    0.05474 (2) obj. -2151.31 iterations 4
# Cbc0038I Pass  12: suminf.    0.05474 (2) obj. -2151.31 iterations 3
# Cbc0038I Pass  13: suminf.    0.05474 (2) obj. -2151.31 iterations 1
# Cbc0038I Pass  14: suminf.    0.05474 (2) obj. -2151.31 iterations 1
# Cbc0038I Pass  15: suminf.    0.05474 (2) obj. -2151.31 iterations 0
# Cbc0038I Pass  16: suminf.    0.05474 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass  17: suminf.    0.42974 (2) obj. -2151.31 iterations 4
# Cbc0038I Pass  18: suminf.    0.63868 (2) obj. -2151.31 iterations 6
# Cbc0038I Pass  19: suminf.    0.42974 (2) obj. -2151.31 iterations 5
# Cbc0038I Pass  20: suminf.    0.42974 (2) obj. -2151.31 iterations 3
# Cbc0038I Pass  21: suminf.    0.42974 (2) obj. -2151.31 iterations 1
# Cbc0038I Pass  22: suminf.    0.42974 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass  23: suminf.    0.42974 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass  24: suminf.    0.63868 (2) obj. -2151.31 iterations 1
# Cbc0038I Pass  25: suminf.    0.05474 (2) obj. -2151.31 iterations 5
# Cbc0038I Pass  26: suminf.    0.05474 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass  27: suminf.    0.33573 (2) obj. -2151.31 iterations 3
# Cbc0038I Pass  28: suminf.    0.05474 (2) obj. -2151.31 iterations 2
# Cbc0038I Pass  29: suminf.    0.33573 (2) obj. -2151.31 iterations 3
# Cbc0038I Pass  30: suminf.    0.33573 (2) obj. -2151.31 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 463 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 467 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -2150 - took 0.01 seconds
# Cbc0012I Integer solution of -2150 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -2154.1379 to -2059 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 4.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -2150, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 454 variables fixed on reduced cost
# Cuts at root node changed objective from -2154.14 to -2059
# Probing was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2150.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Andrew Robertson | DEF | Liverpool | 166 | 70
# Bukayo Saka | MID | Arsenal | 155 | 62
# João Pedro Cavaco Cancelo | DEF | Man City | 153 | 60
# Mason Mount | MID | Chelsea | 139 | 74
# Aaron Ramsdale | GK | Arsenal | 112 | 45
# Mohamed Salah | MID | Liverpool | 206 | 125
# Jarrod Bowen | MID | West Ham | 163 | 63
# José Malheiro de Sá | GK | Wolves | 129 | 50
# Teemu Pukki | FWD | Norwich | 109 | 59
# Ivan Toney | FWD | Brentford | 107 | 63
# Trent Alexander-Arnold | DEF | Liverpool | 168 | 76
# Conor Coady | DEF | Wolves | 116 | 45
# Gabriel Magalhães | DEF | Arsenal | 119 | 50
# Heung-Min Son | MID | Spurs | 198 | 100
# Emmanuel Dennis | FWD | Watford | 110 | 53
# {1: 2477.0, 2: 2414.0, 3: 2361.0, 4: 2300.0, 5: 2230.0, 6: 2150.0}
# {1: {0: 'Bukayo Saka', 1: 'João Pedro Cavaco Cancelo', 2: 'Aymeric Laporte', 3: 'Mohamed Salah', 4: 'Jarrod Bowen', 5: 'Virgil van Dijk', 6: 'José Malheiro de Sá', 7: 'James Ward-Prowse', 8: 'Teemu Pukki', 9: 'Ivan Toney', 10: 'Trent Alexander-Arnold', 11: 'Conor Coady', 12: 'Hugo Lloris', 13: 'Heung-Min Son', 14: 'Emmanuel Dennis'}, 2: {0: 'Bukayo Saka', 1: 'João Pedro Cavaco Cancelo', 2: 'Aymeric Laporte', 3: 'Aaron Ramsdale', 4: 'Mohamed Salah', 5: 'Jarrod Bowen', 6: 'José Malheiro de Sá', 7: 'James Ward-Prowse', 8: 'Teemu Pukki', 9: 'Ivan Toney', 10: 'Trent Alexander-Arnold', 11: 'Gabriel Magalhães', 12: 'Heung-Min Son', 13: 'Emmanuel Dennis', 14: 'Andrew Robertson'}, 3: {0: 'Bukayo Saka', 1: 'João Pedro Cavaco Cancelo', 2: 'Aymeric Laporte', 3: 'Aaron Ramsdale', 4: 'Mohamed Salah', 5: 'Jarrod Bowen', 6: 'James Ward-Prowse', 7: 'José Malheiro de Sá', 8: 'Teemu Pukki', 9: 'Ivan Toney', 10: 'Trent Alexander-Arnold', 11: 'Gabriel Magalhães', 12: 'Heung-Min Son', 13: 'Emmanuel Dennis', 14: 'Andrew Robertson'}, 4: {0: 'Andrew Robertson', 1: 'Bukayo Saka', 2: 'João Pedro Cavaco Cancelo', 3: 'Aaron Ramsdale', 4: 'Mohamed Salah', 5: 'Jarrod Bowen', 6: 'José Malheiro de Sá', 7: 'Matthew Cash', 8: 'Teemu Pukki', 9: 'Ivan Toney', 10: 'Trent Alexander-Arnold', 11: 'Bernardo Mota Veiga de Carvalho e Silva', 12: 'Gabriel Magalhães', 13: 'Heung-Min Son', 14: 'Emmanuel Dennis'}, 5: {0: 'Andrew Robertson', 1: 'Bukayo Saka', 2: 'João Pedro Cavaco Cancelo', 3: 'Mason Mount', 4: 'Aaron Ramsdale', 5: 'Mohamed Salah', 6: 'Jarrod Bowen', 7: 'José Malheiro de Sá', 8: 'Matthew Cash', 9: 'Teemu Pukki', 10: 'Ivan Toney', 11: 'Trent Alexander-Arnold', 12: 'Gabriel Magalhães', 13: 'Heung-Min Son', 14: 'Emmanuel Dennis'}, 6: {0: 'Andrew Robertson', 1: 'Bukayo Saka', 2: 'João Pedro Cavaco Cancelo', 3: 'Mason Mount', 4: 'Aaron Ramsdale', 5: 'Mohamed Salah', 6: 'Jarrod Bowen', 7: 'José Malheiro de Sá', 8: 'Teemu Pukki', 9: 'Ivan Toney', 10: 'Trent Alexander-Arnold', 11: 'Conor Coady', 12: 'Gabriel Magalhães', 13: 'Heung-Min Son', 14: 'Emmanuel Dennis'}}
