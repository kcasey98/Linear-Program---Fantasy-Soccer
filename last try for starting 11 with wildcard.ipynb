# %%
import pandas as pd
from pulp import *
PATH = 'data/'

# Read in gameweek data
current_df = pd.read_csv(PATH + '2021-22/gws/merged_gw.csv', index_col=False)
gw_35 = current_df[current_df.GW == 35]

# Create the dictionary 
GW_dict = {}
GWs = current_df.GW.unique()

points_perGW = {}
#for m in range(35):
    
# Solving for the first x weeks, first part before free hit
players = current_df[current_df.GW == 1].name.unique()
for GW in sorted(GWs)[24:25]:
    print(GW)
    player_price_dict = {} # key: player, value: (name, team, position, price, total points)
    print("Number players in week {} is {}".format(GW, len(players)))
    for i, player in enumerate(players):
        player_entries = current_df[current_df.name == player]
        total_points = player_entries[player_entries.GW <= GW]['total_points'].sum()
        player_team = player_entries[player_entries.GW == 1]['team'].values[0]
        player_price = player_entries[player_entries.GW == 1]['value'].values[0]
        player_position = player_entries[player_entries.GW == 1]['position'].values[0]
        player_name = player_entries[player_entries.GW == 1]['name']
        if player not in player_price_dict:
                val = (player,player_team, player_position, player_price, total_points)
                player_price_dict[player] = val
    GW_dict[GW] = player_price_dict
    #print("Player {} had {} price total in all {} played.".format(player, player_price, len(player_entries)))


# # Solving for the best teams from each week x until end, second half!!!!!!!!!!!! done :0
# for GW in sorted(GWs)[25:26]:
#     player_price_dict = {} # key: player, value: (name, team, position, price, total points)
#     players = current_df[current_df.GW == GW].name.unique()
#     # print("Number players in week {} is {}".format(GW, len(players)))
#     for i, player in enumerate(players):
#         player_entries = current_df[current_df.name == player]
#         total_points = player_entries[player_entries.GW >= GW]['total_points'].sum()
#         player_team = player_entries[player_entries.GW == GW]['team'].values[0]
#         player_price = player_entries[player_entries.GW == GW]['value'].values[0]
#         player_position = player_entries[player_entries.GW == GW]['position'].values[0]
#         player_name = player_entries[player_entries.GW == GW]['name']
#         if player not in player_price_dict:
#                 val = (player,player_team, player_position, player_price, total_points)
#                 player_price_dict[player] = val             
#     GW_dict[GW] = player_price_dict
#         #print("Player {} had {} price total in all {} played.".format(player, player_price, len(player_entries)))



gw_35.head()
data = gw_35[['name', 'team', 'position', 'total_points', 'value']]        
data.head()

# Helper variables
POS = data.position.unique()
CLUBS = data.team.unique()

BUDGET = 1000
pos_available = {
'DEF': 5,
'FWD': 3,
'MID': 5,
'GK': 2,
}

# Initialize Variables
solver_dict = {}
points_dict = {}
for GW in GWs[24:25]:
    # print(GW)
    cur_player_price_dict = GW_dict[GW]
    names, teams, positions, prices, points = list(zip(*cur_player_price_dict.values()))
    players = [LpVariable("player_" + str(i), cat="Binary") for i in range(len(names))]

    # Initialize the problem
    prob = LpProblem("FPL_Player_Choices", LpMaximize)
    # Define the objective
    prob += lpSum(players[i] * points[i] for i in range(len(names))) # Objective
    # Build the constraints
    prob += lpSum(players[i] * prices[i] for i in range(len(names))) <= BUDGET # Budget Limit

    for pos in POS:
        prob += lpSum(players[i] for i in range(len(names)) if positions[i] == pos) <= pos_available[pos]
    for club in CLUBS:
        prob += lpSum(players[i] for i in range(len(names)) if teams[i] == club) <= 3 # Club Limit

    # Solve the problem
    prob.solve()
    for v in prob.variables():
        if v.varValue != 0:
            index = int(v.name.split("_")[1])
            name = names[index]
            club = teams[index]
            position = positions[index]
            point = points[index]
            price = prices[index]
            # week_point = week_points[index]
            print(name, position, club, point, price, sep=" | ")
            score = str(prob.objective)
            constraint = [str(const) for const in prob.constraints.values()][0]
            solver_dict[name] = name, position, club, point, price, 
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraint = constraint.replace(v.name, str(v.varValue))

    score_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', score) )
    constraint_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', constraint) )

    # print(value(prob.objective))
    points_dict[GW] = value(prob.objective)


names, positions, clubs, points, prices = list(zip(*solver_dict.values()))
totals_dict = [0]*35
my_team = {}
for i in range(len(names)):
    for GW in sorted(GWs)[:35]:
        player_entries = current_df[current_df.name == names[i]]
        points = player_entries[player_entries.GW == GW]['total_points'].sum()
        totals_dict[GW-1] = points
    my_team[names[i]] = names[i], positions[i], clubs[i], prices[i], totals_dict
    totals_dict = [0]*35
#print(my_team)


#Solve again 4-4-2
# Helper variables
POS = data.position.unique()
CLUBS = data.team.unique()

BUDGET = 1000
pos_available = {
'DEF': [3,5], #3 to 5
'FWD': [1,3], #1 to 3
'MID': [2,5], #2 to 5
'GK': [1,1], #have to have 1 goalie (2)
} # total adds to 11

# Initialize Variables
solver_dict = {}
points_dict = {}
points_total = 0;
for GW in GWs[0:25]:
    names, positions, teams, prices, points = list(zip(*my_team.values()))
    players = [LpVariable("player_" + str(i), cat="Binary") for i in range(len(names))]
    #posi = [LpVariable("pos_" + str(i), cat="Integer") for i in range(4)]

    # Initialie the problem
    prob = LpProblem("FPL_Player_Choices", LpMaximize)
    # Define the objective
    prob += lpSum(players[i] * points[i][GW-1] for i in range(len(names))) # Objective

    #prob += lpSum(posi[i] for i in range(len(names))   ) == 11

    for pos in POS:
        prob += lpSum(players[i] for i in range(len(names)) if positions[i] == pos) <= pos_available[pos][1]
        prob += lpSum(players[i] for i in range(len(names)) if positions[i] == pos) >= pos_available[pos][0]

    prob += lpSum(players[i] for i in range(len(names))) == 11

    # Solve the problem
    prob.solve()
    captain = 0;
    for v in prob.variables():
        if v.varValue != 0:
            index = int(v.name.split("_")[1])
            name = names[index]
            club = teams[index]
            position = positions[index]
            point = points[index][GW-1]
            if point > captain:
                captain = point
            price = prices[index]
            print(name, position, club, point, price, sep=" | ")
            score = str(prob.objective)
            constraint = [str(const) for const in prob.constraints.values()][0]
            solver_dict[name] = name, position, club, point, price
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraint = constraint.replace(v.name, str(v.varValue))

    score_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', score) )
    constraint_pretty = " + ".join( re.findall('[0-9\.]*\*1.0', constraint) )

    points_dict[GW] = value(prob.objective) + captain
    points_total += value(prob.objective) + captain
#     points += captain
    print(GW)
    print(value(prob.objective) + captain)
    print("New Total")
    print(points_total)
    points_perGW[GW] = value(prob.objective) + captain
    captain = 0

print("Final")
print(points_total)

print(points_perGW)
# Out:
# 25
# Number players in week 25 is 553
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/16f452f0d0b8402fa3c8ece47552a539-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/16f452f0d0b8402fa3c8ece47552a539-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 30 COLUMNS
# At line 3236 RHS
# At line 3262 BOUNDS
# At line 3816 ENDATA
# Problem MODEL has 25 rows, 553 columns and 1659 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1792.86 - 0.00 seconds
# Cgl0004I processed model has 25 rows, 437 columns (437 integer (434 of which binary)) and 1311 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.71429
# Cbc0038I Pass   1: suminf.    0.12000 (1) obj. -1776.28 iterations 6
# Cbc0038I Solution found of -1617
# Cbc0038I Cleaned solution of -1617
# Cbc0038I Rounding solution of -1688 is better than previous of -1617
#
# Cbc0038I Before mini branch and bound, 432 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 437 columns, reduced to 4 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -1688 to -1786 (0.01 seconds)
# Cbc0038I Round again with cutoff of -1787.59
# Cbc0038I Reduced cost fixing fixed 422 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.91845 (2) obj. -1787.59 iterations 4
# Cbc0038I Pass   3: suminf.    0.39779 (2) obj. -1787.59 iterations 4
# Cbc0038I Pass   4: suminf.    0.39779 (2) obj. -1787.59 iterations 0
# Cbc0038I Pass   5: suminf.    0.39779 (2) obj. -1787.59 iterations 0
# Cbc0038I Pass   6: suminf.    2.48067 (6) obj. -1787.59 iterations 4
# Cbc0038I Pass   7: suminf.    1.61425 (5) obj. -1787.59 iterations 5
# Cbc0038I Pass   8: suminf.    1.39641 (5) obj. -1787.59 iterations 2
# Cbc0038I Pass   9: suminf.    0.26427 (2) obj. -1787.59 iterations 4
# Cbc0038I Pass  10: suminf.    0.26427 (2) obj. -1787.59 iterations 1
# Cbc0038I Pass  11: suminf.    0.95851 (2) obj. -1787.59 iterations 5
# Cbc0038I Pass  12: suminf.    0.95851 (2) obj. -1787.59 iterations 1
# Cbc0038I Pass  13: suminf.    1.00000 (3) obj. -1787.59 iterations 3
# Cbc0038I Pass  14: suminf.    0.95851 (2) obj. -1787.59 iterations 3
# Cbc0038I Pass  15: suminf.    0.95851 (2) obj. -1787.59 iterations 3
# Cbc0038I Pass  16: suminf.    1.93504 (6) obj. -1787.59 iterations 7
# Cbc0038I Pass  17: suminf.    0.59760 (2) obj. -1787.59 iterations 3
# Cbc0038I Pass  18: suminf.    0.77141 (2) obj. -1787.59 iterations 5
# Cbc0038I Pass  19: suminf.    0.65087 (2) obj. -1787.59 iterations 3
# Cbc0038I Pass  20: suminf.    0.65087 (2) obj. -1787.59 iterations 2
# Cbc0038I Pass  21: suminf.    0.73573 (2) obj. -1787.59 iterations 4
# Cbc0038I Pass  22: suminf.    1.15596 (5) obj. -1787.59 iterations 4
# Cbc0038I Pass  23: suminf.    1.15262 (5) obj. -1787.59 iterations 2
# Cbc0038I Pass  24: suminf.    0.52854 (4) obj. -1787.59 iterations 3
# Cbc0038I Pass  25: suminf.    0.26427 (2) obj. -1787.59 iterations 2
# Cbc0038I Pass  26: suminf.    0.95851 (2) obj. -1787.59 iterations 6
# Cbc0038I Pass  27: suminf.    0.95851 (2) obj. -1787.59 iterations 1
# Cbc0038I Pass  28: suminf.    1.00000 (3) obj. -1787.59 iterations 3
# Cbc0038I Pass  29: suminf.    0.95851 (2) obj. -1787.59 iterations 3
# Cbc0038I Pass  30: suminf.    0.95851 (2) obj. -1787.59 iterations 2
# Cbc0038I Pass  31: suminf.    1.00000 (3) obj. -1787.59 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 425 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 25 rows 437 columns, reduced to 5 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -1786 - took 0.02 seconds
# Cbc0012I Integer solution of -1786 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 25 rows 437 columns, reduced to 4 rows 4 columns
# Cbc0031I 1 added rows had average density of 8
# Cbc0013I At root node, 1 cuts changed objective from -1792.8571 to -1792.6667 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -1786, took 1 iterations and 0 nodes (0.03 seconds)
# Cbc0032I Strong branching done 8 times (19 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 418 variables fixed on reduced cost
# Cuts at root node changed objective from -1792.86 to -1785
# Probing was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1786.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# João Pedro Cavaco Cancelo | DEF | Man City | 141 | 60
# Mohamed Salah | MID | Liverpool | 181 | 125
# Jarrod Bowen | MID | West Ham | 148 | 65
# Conor Gallagher | MID | Crystal Palace | 105 | 55
# Antonio Rüdiger | DEF | Chelsea | 102 | 55
# Diogo Jota | MID | Liverpool | 126 | 75
# José Malheiro de Sá | GK | Wolves | 108 | 50
# Allan Saint-Maximin | FWD | Newcastle | 91 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 156 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 114 | 60
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 114 | 70
# Gabriel Magalhães | DEF | Arsenal | 98 | 50
# David de Gea | GK | Man Utd | 102 | 50
# Michail Antonio | FWD | West Ham | 104 | 75
# Emmanuel Dennis | FWD | Watford | 96 | 50
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/ad40deffdb144a9d9414e48f56bbc863-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/ad40deffdb144a9d9414e48f56bbc863-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 102 RHS
# At line 112 BOUNDS
# At line 128 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 77 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (11 of which binary)) and 24 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -77
# Cbc0038I Cleaned solution of -77
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -77 - took 0.00 seconds
# Cbc0012I Integer solution of -77 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -77, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -77 to -77
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                77.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 2 | 60
# Mohamed Salah | MID | Liverpool | 17 | 125
# Michail Antonio | FWD | West Ham | 13 | 75
# Emmanuel Dennis | FWD | Watford | 12 | 50
# Jarrod Bowen | MID | West Ham | 2 | 65
# Antonio Rüdiger | DEF | Chelsea | 6 | 55
# Diogo Jota | MID | Liverpool | 8 | 75
# José Malheiro de Sá | GK | Wolves | 3 | 50
# Allan Saint-Maximin | FWD | Newcastle | 6 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 6 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 2 | 60
# 1
# 94.0
# New Total
# 94.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/b2e9593c971a46ec8121480f3feda322-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/b2e9593c971a46ec8121480f3feda322-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 104 RHS
# At line 114 BOUNDS
# At line 130 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 73 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 11 columns (11 integer (9 of which binary)) and 22 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -73
# Cbc0038I Cleaned solution of -73
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -73 - took 0.00 seconds
# Cbc0012I Integer solution of -73 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -73, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -73 to -73
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                73.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 6 | 60
# Mohamed Salah | MID | Liverpool | 3 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 3 | 70
# David de Gea | GK | Man Utd | 3 | 50
# Michail Antonio | FWD | West Ham | 16 | 75
# Jarrod Bowen | MID | West Ham | 2 | 65
# Conor Gallagher | MID | Crystal Palace | 3 | 55
# Antonio Rüdiger | DEF | Chelsea | 6 | 55
# Diogo Jota | MID | Liverpool | 8 | 75
# Trent Alexander-Arnold | DEF | Liverpool | 12 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 11 | 60
# 2
# 89.0
# New Total
# 183.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/2f0e1ce791b24680b5f4d3b85c424065-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/2f0e1ce791b24680b5f4d3b85c424065-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 104 RHS
# At line 114 BOUNDS
# At line 130 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 72 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 13 columns (13 integer (13 of which binary)) and 26 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -72
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -72 - took 0.00 seconds
# Cbc0012I Integer solution of -72 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -72, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -72 to -72
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                72.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# João Pedro Cavaco Cancelo | DEF | Man City | 6 | 60
# Mohamed Salah | MID | Liverpool | 10 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 4 | 70
# David de Gea | GK | Man Utd | 7 | 50
# Michail Antonio | FWD | West Ham | 11 | 75
# Jarrod Bowen | MID | West Ham | 2 | 65
# Conor Gallagher | MID | Crystal Palace | 15 | 55
# Diogo Jota | MID | Liverpool | 1 | 75
# Allan Saint-Maximin | FWD | Newcastle | 6 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 4 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 6 | 60
# 3
# 87.0
# New Total
# 270.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/faaaf6c05ef1485fb65fd044ecde2c0f-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/faaaf6c05ef1485fb65fd044ecde2c0f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 105 RHS
# At line 115 BOUNDS
# At line 131 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 85 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 13 columns (13 integer (13 of which binary)) and 26 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -85
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -85 - took 0.00 seconds
# Cbc0012I Integer solution of -85 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -85, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -85 to -85
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                85.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 12 | 60
# Mohamed Salah | MID | Liverpool | 8 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 10 | 70
# Gabriel Magalhães | DEF | Arsenal | 8 | 50
# Conor Gallagher | MID | Crystal Palace | 8 | 55
# Antonio Rüdiger | DEF | Chelsea | 6 | 55
# Diogo Jota | MID | Liverpool | 3 | 75
# José Malheiro de Sá | GK | Wolves | 6 | 50
# Allan Saint-Maximin | FWD | Newcastle | 5 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 12 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 7 | 60
# 4
# 97.0
# New Total
# 367.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/4c59945ef7494cdba02e1973e6e46d0e-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/4c59945ef7494cdba02e1973e6e46d0e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 102 RHS
# At line 112 BOUNDS
# At line 128 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 82 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 13 columns (13 integer (13 of which binary)) and 26 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -82
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -82 - took 0.00 seconds
# Cbc0012I Integer solution of -82 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -82, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -82 to -82
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                82.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 6 | 60
# Mohamed Salah | MID | Liverpool | 12 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 3 | 70
# Gabriel Magalhães | DEF | Arsenal | 7 | 50
# David de Gea | GK | Man Utd | 10 | 50
# Emmanuel Dennis | FWD | Watford | 6 | 50
# Jarrod Bowen | MID | West Ham | 5 | 65
# Antonio Rüdiger | DEF | Chelsea | 14 | 55
# Diogo Jota | MID | Liverpool | 3 | 75
# Allan Saint-Maximin | FWD | Newcastle | 8 | 65
# Rúben Santos Gato Alves Dias | DEF | Man City | 8 | 60
# 5
# 96.0
# New Total
# 463.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/8642c341f90b478f9a1b0fc860006d1a-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/8642c341f90b478f9a1b0fc860006d1a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 105 RHS
# At line 115 BOUNDS
# At line 131 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 75 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (11 of which binary)) and 24 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -75
# Cbc0038I Cleaned solution of -75
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -75 - took 0.00 seconds
# Cbc0012I Integer solution of -75 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -75, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -75 to -75
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                75.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 12 | 60
# Mohamed Salah | MID | Liverpool | 7 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 3 | 70
# Gabriel Magalhães | DEF | Arsenal | 2 | 50
# Michail Antonio | FWD | West Ham | 8 | 75
# Jarrod Bowen | MID | West Ham | 5 | 65
# Conor Gallagher | MID | Crystal Palace | 4 | 55
# Diogo Jota | MID | Liverpool | 7 | 75
# José Malheiro de Sá | GK | Wolves | 14 | 50
# Allan Saint-Maximin | FWD | Newcastle | 8 | 65
# Rúben Santos Gato Alves Dias | DEF | Man City | 5 | 60
# 6
# 89.0
# New Total
# 552.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/91864b09ea0c4beb9c27fa1d68bcd04e-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/91864b09ea0c4beb9c27fa1d68bcd04e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 102 RHS
# At line 112 BOUNDS
# At line 128 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 39 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 11 columns (11 integer (9 of which binary)) and 22 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -39
# Cbc0038I Cleaned solution of -39
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -39 - took 0.00 seconds
# Cbc0012I Integer solution of -39 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -39, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -39 to -39
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                39.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 0 | 60
# Mohamed Salah | MID | Liverpool | 13 | 125
# Gabriel Magalhães | DEF | Arsenal | 6 | 50
# David de Gea | GK | Man Utd | 2 | 50
# Michail Antonio | FWD | West Ham | 2 | 75
# Emmanuel Dennis | FWD | Watford | 1 | 50
# Jarrod Bowen | MID | West Ham | 7 | 65
# Conor Gallagher | MID | Crystal Palace | 2 | 55
# Antonio Rüdiger | DEF | Chelsea | 2 | 55
# Diogo Jota | MID | Liverpool | 2 | 75
# Allan Saint-Maximin | FWD | Newcastle | 2 | 65
# 7
# 52.0
# New Total
# 604.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/808a8ad212ef4553ab42e3db148834dd-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/808a8ad212ef4553ab42e3db148834dd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 103 RHS
# At line 113 BOUNDS
# At line 129 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 52 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (11 of which binary)) and 24 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -52
# Cbc0038I Cleaned solution of -52
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -52 - took 0.00 seconds
# Cbc0012I Integer solution of -52 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -52, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -52 to -52
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                52.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 6 | 60
# Mohamed Salah | MID | Liverpool | 13 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 11 | 70
# David de Gea | GK | Man Utd | 2 | 50
# Michail Antonio | FWD | West Ham | 1 | 75
# Emmanuel Dennis | FWD | Watford | 2 | 50
# Jarrod Bowen | MID | West Ham | 6 | 65
# Conor Gallagher | MID | Crystal Palace | 2 | 55
# Allan Saint-Maximin | FWD | Newcastle | 2 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 6 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 1 | 60
# 8
# 65.0
# New Total
# 669.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/d5de2d8f950e47a49a026f7a18ac1d9d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/d5de2d8f950e47a49a026f7a18ac1d9d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 105 RHS
# At line 115 BOUNDS
# At line 131 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 88 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 13 columns (13 integer (13 of which binary)) and 26 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -88
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -88 - took 0.00 seconds
# Cbc0012I Integer solution of -88 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -88, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -88 to -88
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                88.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Mohamed Salah | MID | Liverpool | 24 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 5 | 70
# Michail Antonio | FWD | West Ham | 7 | 75
# Emmanuel Dennis | FWD | Watford | 12 | 50
# Jarrod Bowen | MID | West Ham | 3 | 65
# Antonio Rüdiger | DEF | Chelsea | 9 | 55
# Diogo Jota | MID | Liverpool | 11 | 75
# José Malheiro de Sá | GK | Wolves | 3 | 50
# Allan Saint-Maximin | FWD | Newcastle | 2 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 10 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 2 | 60
# 9
# 112.0
# New Total
# 781.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/a0746fae8280448e8899582c0176ceaf-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/a0746fae8280448e8899582c0176ceaf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 104 RHS
# At line 114 BOUNDS
# At line 130 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 64 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (11 of which binary)) and 24 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -64
# Cbc0038I Cleaned solution of -64
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -64 - took 0.00 seconds
# Cbc0012I Integer solution of -64 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -64, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -64 to -64
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                64.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# João Pedro Cavaco Cancelo | DEF | Man City | 2 | 60
# Mohamed Salah | MID | Liverpool | 5 | 125
# Gabriel Magalhães | DEF | Arsenal | 15 | 50
# David de Gea | GK | Man Utd | 6 | 50
# Michail Antonio | FWD | West Ham | 2 | 75
# Jarrod Bowen | MID | West Ham | 11 | 65
# Conor Gallagher | MID | Crystal Palace | 13 | 55
# Antonio Rüdiger | DEF | Chelsea | 6 | 55
# Allan Saint-Maximin | FWD | Newcastle | 2 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 1 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 1 | 60
# 10
# 79.0
# New Total
# 860.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/1f121239347449e59d8d4b21bb4f61c3-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/1f121239347449e59d8d4b21bb4f61c3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 105 RHS
# At line 115 BOUNDS
# At line 131 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 76 - 0.00 seconds
# Cgl0004I processed model has 3 rows, 11 columns (11 integer (10 of which binary)) and 21 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -76
# Cbc0038I Cleaned solution of -76
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -76 - took 0.00 seconds
# Cbc0012I Integer solution of -76 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -76, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -76 to -76
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                76.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 14 | 60
# Mohamed Salah | MID | Liverpool | 5 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 8 | 70
# Gabriel Magalhães | DEF | Arsenal | 5 | 50
# David de Gea | GK | Man Utd | 2 | 50
# Michail Antonio | FWD | West Ham | 2 | 75
# Emmanuel Dennis | FWD | Watford | 2 | 50
# Jarrod Bowen | MID | West Ham | 9 | 65
# Conor Gallagher | MID | Crystal Palace | 11 | 55
# Trent Alexander-Arnold | DEF | Liverpool | 12 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 6 | 60
# 11
# 90.0
# New Total
# 950.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/bbfb9060cbb74605beac3773632a413f-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/bbfb9060cbb74605beac3773632a413f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 103 RHS
# At line 113 BOUNDS
# At line 129 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 104 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (11 of which binary)) and 24 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -104
# Cbc0038I Cleaned solution of -104
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -104 - took 0.00 seconds
# Cbc0012I Integer solution of -104 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -104, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -104 to -104
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                104.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 12 | 60
# Mohamed Salah | MID | Liverpool | 8 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 8 | 70
# Emmanuel Dennis | FWD | Watford | 14 | 50
# Jarrod Bowen | MID | West Ham | 2 | 65
# Conor Gallagher | MID | Crystal Palace | 5 | 55
# Antonio Rüdiger | DEF | Chelsea | 14 | 55
# Diogo Jota | MID | Liverpool | 8 | 75
# José Malheiro de Sá | GK | Wolves | 8 | 50
# ...
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -62 - took 0.00 seconds
# Cbc0012I Integer solution of -62 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -62, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -62 to -62
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                62.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 2 | 60
# Mohamed Salah | MID | Liverpool | 7 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 5 | 70
# Michail Antonio | FWD | West Ham | 9 | 75
# Emmanuel Dennis | FWD | Watford | 1 | 50
# Jarrod Bowen | MID | West Ham | 21 | 65
# Antonio Rüdiger | DEF | Chelsea | 1 | 55
# Diogo Jota | MID | Liverpool | 5 | 75
# José Malheiro de Sá | GK | Wolves | 5 | 50
# Trent Alexander-Arnold | DEF | Liverpool | 4 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 2 | 60
# 21
# 83.0
# New Total
# 1758.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/5f6c92cff4154f63b4202fcf78ea9bef-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/5f6c92cff4154f63b4202fcf78ea9bef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 102 RHS
# At line 112 BOUNDS
# At line 128 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 69 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 13 columns (13 integer (13 of which binary)) and 26 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -69
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -69 - took 0.00 seconds
# Cbc0012I Integer solution of -69 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -69, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -69 to -69
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                69.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# João Pedro Cavaco Cancelo | DEF | Man City | 11 | 60
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 3 | 70
# David de Gea | GK | Man Utd | 8 | 50
# Michail Antonio | FWD | West Ham | 4 | 75
# Emmanuel Dennis | FWD | Watford | 2 | 50
# Jarrod Bowen | MID | West Ham | 7 | 65
# Conor Gallagher | MID | Crystal Palace | 9 | 55
# Antonio Rüdiger | DEF | Chelsea | 3 | 55
# Diogo Jota | MID | Liverpool | 3 | 75
# Allan Saint-Maximin | FWD | Newcastle | 9 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 10 | 75
# 22
# 80.0
# New Total
# 1838.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/2af4b63cd6114be5b050e39a8610730d-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/2af4b63cd6114be5b050e39a8610730d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 104 RHS
# At line 114 BOUNDS
# At line 130 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 37 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 11 columns (11 integer (9 of which binary)) and 22 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -37
# Cbc0038I Cleaned solution of -37
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -37 - took 0.00 seconds
# Cbc0012I Integer solution of -37 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -37, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -37 to -37
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                37.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# João Pedro Cavaco Cancelo | DEF | Man City | 2 | 60
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 2 | 70
# Gabriel Magalhães | DEF | Arsenal | 6 | 50
# David de Gea | GK | Man Utd | 6 | 50
# Michail Antonio | FWD | West Ham | 2 | 75
# Jarrod Bowen | MID | West Ham | 2 | 65
# Antonio Rüdiger | DEF | Chelsea | 7 | 55
# Diogo Jota | MID | Liverpool | 5 | 75
# Allan Saint-Maximin | FWD | Newcastle | 1 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 2 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 2 | 60
# 23
# 44.0
# New Total
# 1882.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/4aff6ea5ac5649f59cc34efa149f13be-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/4aff6ea5ac5649f59cc34efa149f13be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 104 RHS
# At line 114 BOUNDS
# At line 130 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 74 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 11 columns (11 integer (9 of which binary)) and 22 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -74
# Cbc0038I Cleaned solution of -74
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -74 - took 0.00 seconds
# Cbc0012I Integer solution of -74 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -74, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -74 to -74
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                74.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# João Pedro Cavaco Cancelo | DEF | Man City | 7 | 60
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 3 | 70
# Gabriel Magalhães | DEF | Arsenal | 14 | 50
# David de Gea | GK | Man Utd | 2 | 50
# Michail Antonio | FWD | West Ham | 2 | 75
# Emmanuel Dennis | FWD | Watford | 2 | 50
# Jarrod Bowen | MID | West Ham | 11 | 65
# Diogo Jota | MID | Liverpool | 16 | 75
# Allan Saint-Maximin | FWD | Newcastle | 5 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 6 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 6 | 60
# 24
# 90.0
# New Total
# 1972.0
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/2cb48d2d61be4ae6a998e70fff2af080-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/3s/js3l59qs4q73dcnvx8spqhq40000gn/T/2cb48d2d61be4ae6a998e70fff2af080-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 102 RHS
# At line 112 BOUNDS
# At line 128 ENDATA
# Problem MODEL has 9 rows, 15 columns and 45 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 53 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (8 of which binary)) and 20 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -53
# Cbc0038I Cleaned solution of -53
# Cbc0038I Before mini branch and bound, 10 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -53 - took 0.00 seconds
# Cbc0012I Integer solution of -53 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -53, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -53 to -53
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                53.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Mohamed Salah | MID | Liverpool | 3 | 125
# Bernardo Mota Veiga de Carvalho e Silva | MID | Man City | 3 | 70
# David de Gea | GK | Man Utd | 10 | 50
# Michail Antonio | FWD | West Ham | 2 | 75
# Jarrod Bowen | MID | West Ham | 13 | 65
# Conor Gallagher | MID | Crystal Palace | 3 | 55
# Antonio Rüdiger | DEF | Chelsea | 0 | 55
# Diogo Jota | MID | Liverpool | 1 | 75
# Allan Saint-Maximin | FWD | Newcastle | 2 | 65
# Trent Alexander-Arnold | DEF | Liverpool | 6 | 75
# Rúben Santos Gato Alves Dias | DEF | Man City | 10 | 60
# 25
# 66.0
# New Total
# 2038.0
# Final
# 2038.0
# {1: 94.0, 2: 89.0, 3: 87.0, 4: 97.0, 5: 96.0, 6: 89.0, 7: 52.0, 8: 65.0, 9: 112.0, 10: 79.0, 11: 90.0, 12: 119.0, 13: 81.0, 14: 82.0, 15: 78.0, 16: 107.0, 17: 64.0, 18: 80.0, 19: 52.0, 20: 62.0, 21: 83.0, 22: 80.0, 23: 44.0, 24: 90.0, 25: 66.0}
